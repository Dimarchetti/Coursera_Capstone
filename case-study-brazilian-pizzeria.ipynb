# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          91 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0   conda-forge
#     geopy:         1.20.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '1J3KYSRL4ONN3HV2KKQCOLR5SMGPMWNSZEQ1HLKIL0KHXC42' # your Foursquare ID
CLIENT_SECRET = 'DWQYAPMPPBWZHF2QGBMJMRVEEWI32REH0XP4PFFINCDTABJH' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1J3KYSRL4ONN3HV2KKQCOLR5SMGPMWNSZEQ1HLKIL0KHXC42
# CLIENT_SECRET:DWQYAPMPPBWZHF2QGBMJMRVEEWI32REH0XP4PFFINCDTABJH

# %%
address = 'Maricá, Maricá, RJ, 24900-000'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -22.9196772 -42.8184375

# %%
search_query = 'Pizzaria'
radius = 30000
print(search_query + ' .... OK!')
# Out:
# Pizzaria .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=1J3KYSRL4ONN3HV2KKQCOLR5SMGPMWNSZEQ1HLKIL0KHXC42&client_secret=DWQYAPMPPBWZHF2QGBMJMRVEEWI32REH0XP4PFFINCDTABJH&ll=-22.9196772,-42.8184375&v=20180604&query=Pizzaria&radius=30000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dabb9c7a197930038146f0b'},
#  'response': {'venues': [{'id': '4f42d3dde4b0a2bdc6b74f44',
#     'name': 'Pizzaria Oasis',
#     'location': {'address': 'Maricá',
#      'lat': -22.919149,
#      'lng': -42.818641,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.919149,
#        'lng': -42.818641}],
#      'distance': 62,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Maricá', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '514ba85ee4b0050de1fe467d',
#     'name': 'Pizzaria do Mineiro 2',
#     'location': {'lat': -22.920881271362305,
#      'lng': -42.82231521606445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.920881271362305,
#        'lng': -42.82231521606445}],
#      'distance': 419,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '50ad5cd6e4b01c608604ba15',
#     'name': 'Pizzaria Paulistana II',
#     'location': {'lat': -22.923264149179598,
#      'lng': -42.820784692070184,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.923264149179598,
#        'lng': -42.820784692070184}],
#      'distance': 466,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4f5bea88e4b01f8f4c62e6dc',
#     'name': 'Pizzaria Mundi',
#     'location': {'lat': -22.923254013061523,
#      'lng': -42.82173538208008,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.923254013061523,
#        'lng': -42.82173538208008}],
#      'distance': 522,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '51a3e20c498e55762dc3b103',
#     'name': 'Trayller e pizzaria do mineiro',
#     'location': {'address': 'Rua Alvares de Castro',
#      'lat': -22.92108317423828,
#      'lng': -42.82233260924939,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.92108317423828,
#        'lng': -42.82233260924939}],
#      'distance': 428,
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Alvares de Castro', 'Maricá, RJ', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '51329010e4b02d07e1733453',
#     'name': 'Pizzaria Show Itapeba',
#     'location': {'address': 'Estrada Velha Maricá',
#      'crossStreet': 'Lote 1 - Itapeba',
#      'lat': -22.909086286018837,
#      'lng': -42.82516636747623,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.909086286018837,
#        'lng': -42.82516636747623}],
#      'distance': 1366,
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Estrada Velha Maricá (Lote 1 - Itapeba)',
#       'Maricá, RJ',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '56b9356a498ea9a1a767516d',
#     'name': 'Pizzaria Dom Camilo Forno a Lenha',
#     'location': {'address': 'Rua Raul Alfredo de Andrade, N.62- Loja 1, Caxito',
#      'lat': -22.90746750984462,
#      'lng': -42.82348518188583,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.90746750984462,
#        'lng': -42.82348518188583}],
#      'distance': 1454,
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Raul Alfredo de Andrade, N.62- Loja 1, Caxito',
#       'Maricá, RJ',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4ccb7207c9b84688a60eb6c3',
#     'name': 'Pizzaria Paulistana',
#     'location': {'address': 'R. Euclides dos Santos Quintanilha, 1-649',
#      'lat': -22.905573221508813,
#      'lng': -42.80248088892773,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.905573221508813,
#        'lng': -42.80248088892773}],
#      'distance': 2267,
#      'postalCode': '24900-000',
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Euclides dos Santos Quintanilha, 1-649',
#       'Maricá, RJ',
#       '24900-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4c7164e6fa49a1cdf5b9a8e3',
#     'name': 'Pizzaria Di Lidia',
#     'location': {'address': 'Av. Ewerton da Costa Xavier, 1926',
#      'lat': -22.943262548200035,
#      'lng': -43.02959221347316,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.943262548200035,
#        'lng': -43.02959221347316}],
#      'distance': 21806,
#      'cc': 'BR',
#      'city': 'Niterói',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Ewerton da Costa Xavier, 1926',
#       'Niterói, RJ',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '53f93847498e117d170b3051',
#     'name': 'Pizzaria Coliseu',
#     'location': {'address': 'Rodovia Amaral Peixoto',
#      'crossStreet': 'ao lado do Condado',
#      'lat': -22.901873458501466,
#      'lng': -42.793090527020915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.901873458501466,
#        'lng': -42.793090527020915}],
#      'distance': 3268,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Rodovia Amaral Peixoto (ao lado do Condado)',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '57aa69dc498e64d06e436323',
#     'name': 'Pizzaria Irmãos Gêmeos',
#     'location': {'lat': -22.8919,
#      'lng': -42.800766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.8919,
#        'lng': -42.800766}],
#      'distance': 3583,
#      'postalCode': '24942-395',
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Maricá, RJ', '24942-395', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '500704f7805559aabc059351',
#     'name': 'Pizzaria Brimar',
#     'location': {'address': 'Rua João Saldanha',
#      'crossStreet': 'esquina da Rua Zero - Barra de Maricá',
#      'lat': -22.957464690097385,
#      'lng': -42.82550096511841,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.957464690097385,
#        'lng': -42.82550096511841}],
#      'distance': 4268,
#      'postalCode': '24915-435',
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua João Saldanha (esquina da Rua Zero - Barra de Maricá)',
#       'Maricá, RJ',
#       '24915-435',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '5083543be4b06d381ae82347',
#     'name': 'Pizzaria D Toin',
#     'location': {'address': 'Av. Dr. Eugênio Borges, 33',
#      'lat': -22.886904967691557,
#      'lng': -42.98633922152125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.886904967691557,
#        'lng': -42.98633922152125}],
#      'distance': 17599,
#      'postalCode': '24753-000',
#      'cc': 'BR',
#      'city': 'São Gonçalo',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Dr. Eugênio Borges, 33',
#       'São Gonçalo, RJ',
#       '24753-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '5c1d77be65211f002c566490',
#     'name': 'Olivers Pizzaria',
#     'location': {'lat': -22.908657,
#      'lng': -42.831543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.908657,
#        'lng': -42.831543}],
#      'distance': 1819,
#      'postalCode': '24913-270',
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Maricá, RJ', '24913-270', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '5414e2e9498eec6ac48c7b41',
#     'name': 'Rafa Pizzaria',
#     'location': {'lat': -22.908576,
#      'lng': -42.804107,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.908576,
#        'lng': -42.804107}],
#      'distance': 1919,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4f5d2c62e4b0d8f7b7a34c58',
#     'name': 'Pizzaria do Mineiro',
#     'location': {'address': 'Pç. de São José do Imbassaí',
#      'lat': -22.937651930254777,
#      'lng': -42.89066731299851,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.937651930254777,
#        'lng': -42.89066731299851}],
#      'distance': 7670,
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Pç. de São José do Imbassaí',
#       'Maricá, RJ',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '51045b69e4b09faebb6b7708',
#     'name': 'Pizzaria Rainha',
#     'location': {'address': 'Avenida Central',
#      'lat': -22.957031604670252,
#      'lng': -42.75940675488018,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.957031604670252,
#        'lng': -42.75940675488018}],
#      'distance': 7342,
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Avenida Central', 'Maricá, RJ', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4d76dc37586ef04d44d8dff0',
#     'name': 'Pizzaria Di Lidia',
#     'location': {'address': 'Estrada Caetano Monteiro',
#      'lat': -22.90657505428307,
#      'lng': -43.05610773317559,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.90657505428307,
#        'lng': -43.05610773317559}],
#      'distance': 24413,
#      'cc': 'BR',
#      'city': 'Niterói',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Estrada Caetano Monteiro',
#       'Niterói, RJ',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '52c8b240498e5c700b22206a',
#     'name': 'Pizzaria Miolo Mole',
#     'location': {'lat': -22.955005645751953,
#      'lng': -42.739261627197266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.955005645751953,
#        'lng': -42.739261627197266}],
#      'distance': 9019,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4cb4e5ea56fca1cd23104b18',
#     'name': 'Pizzaria ICRJ',
#     'location': {'address': 'ICRJ',
#      'lat': -22.952212054906717,
#      'lng': -43.171943496731096,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.952212054906717,
#        'lng': -43.171943496731096}],
#      'distance': 36421,
#      'postalCode': '22290-250',
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['ICRJ',
#       'Rio de Janeiro, RJ',
#       '22290-250',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4efe6e50b8f787cacfcfc8f9',
#     'name': 'Pizzaria Vendawal',
#     'location': {'address': 'Canal',
#      'lat': -22.953832119599905,
#      'lng': -42.69667131623569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.953832119599905,
#        'lng': -42.69667131623569}],
#      'distance': 13049,
#      'cc': 'BR',
#      'city': 'Ponta Negra',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Canal', 'Ponta Negra, RJ', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4f1cacfee4b0c74ef32aa626',
#     'name': 'Pizzaria Di Lidia',
#     'location': {'address': 'Av. Vitória Régia, Qd. 15 Lt. 3',
#      'lat': -22.95785988550936,
#      'lng': -42.98103850199414,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.95785988550936,
#        'lng': -42.98103850199414}],
#      'distance': 17202,
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Vitória Régia, Qd. 15 Lt. 3',
#       'Maricá, RJ',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '528ff04c11d241fddffa643b',
#     'name': 'Pizzaria Calçadão da 96',
#     'location': {'address': 'R. Noventa e Seis',
#      'lat': -22.926607791259524,
#      'lng': -42.59549890823039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.926607791259524,
#        'lng': -42.59549890823039}],
#      'distance': 22870,
#      'cc': 'BR',
#      'neighborhood': 'Jaconé',
#      'city': 'Saquarema',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Noventa e Seis', 'Saquarema, RJ', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '58016000d67c14a880633ba1',
#     'name': "Domino's Pizzaria Maricá",
#     'location': {'address': 'Rodovia Amaral Peixoto, km 22,5,',
#      'crossStreet': 'São José de Imbassaí',
#      'lat': -22.92903,
#      'lng': -42.870403,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.92903,
#        'lng': -42.870403}],
#      'distance': 5428,
#      'postalCode': '24942-395',
#      'cc': 'BR',
#      'city': 'Maricá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Rodovia Amaral Peixoto, km 22,5, (São José de Imbassaí)',
#       'Maricá, RJ',
#       '24942-395',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4d571899cff7721eb54dbef5',
#     'name': 'Pizzaria Riviera',
#     'location': {'address': '1',
#      'lat': -22.967550287514797,
#      'lng': -42.93583650358978,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.967550287514797,
#        'lng': -42.93583650358978}],
#      'distance': 13161,
#      'cc': 'BR',
#      'city': 'Itaipuaçu',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['1', 'Itaipuaçu, RJ', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '5132ae56e4b08268835a0fe9',
#     'name': 'Casa das Massas e Pizzaria',
#     'location': {'lat': -22.956775744965643,
#      'lng': -42.75639292363074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.956775744965643,
#        'lng': -42.75639292363074}],
#      'distance': 7583,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4d8942cbd85f3704d6ede3db',
#     'name': 'Pizzaria Mamma Mia',
#     'location': {'address': 'R. Dr. Getúlio Vargas, 1618',
#      'lat': -22.838962138398625,
#      'lng': -43.067667581994975,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.838962138398625,
#        'lng': -43.067667581994975}],
#      'distance': 27094,
#      'postalCode': '24416-000',
#      'cc': 'BR',
#      'city': 'São Gonçalo',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Dr. Getúlio Vargas, 1618',
#       'São Gonçalo, RJ',
#       '24416-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '55ce97c6498e14d772f452a4',
#     'name': 'Pizzaria',
#     'location': {'lat': -22.744428634643555,
#      'lng': -42.85520935058594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.744428634643555,
#        'lng': -42.85520935058594}],
#      'distance': 19869,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '527048d511d2552924e1236a',
#     'name': 'pizzaria água na boca',
#     'location': {'lat': -22.78460693359375,
#      'lng': -42.824951171875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.78460693359375,
#        'lng': -42.824951171875}],
#      'distance': 15050,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False},
#    {'id': '4f404bf7e4b08a9e0a51558d',
#     'name': 'Pizzaria do meu cumpadi',
#     'location': {'lat': -22.96086029415127,
#      'lng': -42.97950004076199,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.96086029415127,
#        'lng': -42.97950004076199}],
#      'distance': 17135,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571535303',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                            name  \
# 0  4f42d3dde4b0a2bdc6b74f44                  Pizzaria Oasis
# 1  514ba85ee4b0050de1fe467d           Pizzaria do Mineiro 2
# 2  50ad5cd6e4b01c608604ba15          Pizzaria Paulistana II
# 3  4f5bea88e4b01f8f4c62e6dc                  Pizzaria Mundi
# 4  51a3e20c498e55762dc3b103  Trayller e pizzaria do mineiro
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571535303    False
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571535303    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571535303    False
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571535303    False
# 4  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571535303    False
#
#         location.address  location.lat  location.lng  \
# 0                 Maricá    -22.919149    -42.818641
# 1                    NaN    -22.920881    -42.822315
# 2                    NaN    -22.923264    -42.820785
# 3                    NaN    -22.923254    -42.821735
# 4  Rua Alvares de Castro    -22.921083    -42.822333
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': -22.919149, 'lng'...                 62
# 1  [{'label': 'display', 'lat': -22.9208812713623...                419
# 2  [{'label': 'display', 'lat': -22.9232641491795...                466
# 3  [{'label': 'display', 'lat': -22.9232540130615...                522
# 4  [{'label': 'display', 'lat': -22.9210831742382...                428
#
#   location.cc location.country                    location.formattedAddress  \
# 0          BR           Brasil                             [Maricá, Brasil]
# 1          BR           Brasil                                     [Brasil]
# 2          BR           Brasil                                     [Brasil]
# 3          BR           Brasil                                     [Brasil]
# 4          BR           Brasil  [Rua Alvares de Castro, Maricá, RJ, Brasil]
#
#   location.city location.state location.crossStreet location.postalCode  \
# 0           NaN            NaN                  NaN                 NaN
# 1           NaN            NaN                  NaN                 NaN
# 2           NaN            NaN                  NaN                 NaN
# 3           NaN            NaN                  NaN                 NaN
# 4        Maricá             RJ                  NaN                 NaN
#
#   location.neighborhood
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                  name            categories  \
# 0                      Pizzaria Oasis           Pizza Place
# 1               Pizzaria do Mineiro 2           Pizza Place
# 2              Pizzaria Paulistana II           Pizza Place
# 3                      Pizzaria Mundi           Pizza Place
# 4      Trayller e pizzaria do mineiro           Pizza Place
# 5               Pizzaria Show Itapeba           Pizza Place
# 6   Pizzaria Dom Camilo Forno a Lenha           Pizza Place
# 7                 Pizzaria Paulistana           Pizza Place
# 8                   Pizzaria Di Lidia           Pizza Place
# 9                    Pizzaria Coliseu           Pizza Place
# 10             Pizzaria Irmãos Gêmeos           Pizza Place
# 11                    Pizzaria Brimar           Pizza Place
# 12                    Pizzaria D Toin           Pizza Place
# 13                   Olivers Pizzaria           Pizza Place
# 14                      Rafa Pizzaria           Pizza Place
# 15                Pizzaria do Mineiro           Pizza Place
# 16                    Pizzaria Rainha           Pizza Place
# 17                  Pizzaria Di Lidia           Pizza Place
# 18                Pizzaria Miolo Mole           Pizza Place
# 19                      Pizzaria ICRJ           Pizza Place
# 20                  Pizzaria Vendawal           Pizza Place
# 21                  Pizzaria Di Lidia           Pizza Place
# 22            Pizzaria Calçadão da 96           Pizza Place
# 23           Domino's Pizzaria Maricá  Fast Food Restaurant
# 24                   Pizzaria Riviera           Pizza Place
# 25         Casa das Massas e Pizzaria    Italian Restaurant
# 26                 Pizzaria Mamma Mia           Pizza Place
# 27                           Pizzaria           Pizza Place
# 28              pizzaria água na boca           Pizza Place
# 29            Pizzaria do meu cumpadi           Pizza Place
#
#                                               address        lat        lng  \
# 0                                              Maricá -22.919149 -42.818641
# 1                                                 NaN -22.920881 -42.822315
# 2                                                 NaN -22.923264 -42.820785
# 3                                                 NaN -22.923254 -42.821735
# 4                               Rua Alvares de Castro -22.921083 -42.822333
# 5                                Estrada Velha Maricá -22.909086 -42.825166
# 6   Rua Raul Alfredo de Andrade, N.62- Loja 1, Caxito -22.907468 -42.823485
# 7           R. Euclides dos Santos Quintanilha, 1-649 -22.905573 -42.802481
# 8                   Av. Ewerton da Costa Xavier, 1926 -22.943263 -43.029592
# 9                              Rodovia Amaral Peixoto -22.901873 -42.793091
# 10                                                NaN -22.891900 -42.800766
# 11                                  Rua João Saldanha -22.957465 -42.825501
# 12                         Av. Dr. Eugênio Borges, 33 -22.886905 -42.986339
# 13                                                NaN -22.908657 -42.831543
# 14                                                NaN -22.908576 -42.804107
# 15                        Pç. de São José do Imbassaí -22.937652 -42.890667
# 16                                    Avenida Central -22.957032 -42.759407
# 17                           Estrada Caetano Monteiro -22.906575 -43.056108
# 18                                                NaN -22.955006 -42.739262
# 19                                               ICRJ -22.952212 -43.171943
# 20                                              Canal -22.953832 -42.696671
# 21                    Av. Vitória Régia, Qd. 15 Lt. 3 -22.957860 -42.981039
# 22                                  R. Noventa e Seis -22.926608 -42.595499
# 23                   Rodovia Amaral Peixoto, km 22,5, -22.929030 -42.870403
# 24                                                  1 -22.967550 -42.935837
# 25                                                NaN -22.956776 -42.756393
# 26                        R. Dr. Getúlio Vargas, 1618 -22.838962 -43.067668
# 27                                                NaN -22.744429 -42.855209
# 28                                                NaN -22.784607 -42.824951
# 29                                                NaN -22.960860 -42.979500
#
#                                        labeledLatLngs  distance  cc country  \
# 0   [{'label': 'display', 'lat': -22.919149, 'lng'...        62  BR  Brasil
# 1   [{'label': 'display', 'lat': -22.9208812713623...       419  BR  Brasil
# 2   [{'label': 'display', 'lat': -22.9232641491795...       466  BR  Brasil
# 3   [{'label': 'display', 'lat': -22.9232540130615...       522  BR  Brasil
# 4   [{'label': 'display', 'lat': -22.9210831742382...       428  BR  Brasil
# 5   [{'label': 'display', 'lat': -22.9090862860188...      1366  BR  Brasil
# 6   [{'label': 'display', 'lat': -22.9074675098446...      1454  BR  Brasil
# 7   [{'label': 'display', 'lat': -22.9055732215088...      2267  BR  Brasil
# 8   [{'label': 'display', 'lat': -22.9432625482000...     21806  BR  Brasil
# 9   [{'label': 'display', 'lat': -22.9018734585014...      3268  BR  Brasil
# 10  [{'label': 'display', 'lat': -22.8919, 'lng': ...      3583  BR  Brasil
# 11  [{'label': 'display', 'lat': -22.9574646900973...      4268  BR  Brasil
# 12  [{'label': 'display', 'lat': -22.8869049676915...     17599  BR  Brasil
# 13  [{'label': 'display', 'lat': -22.908657, 'lng'...      1819  BR  Brasil
# 14  [{'label': 'display', 'lat': -22.908576, 'lng'...      1919  BR  Brasil
# 15  [{'label': 'display', 'lat': -22.9376519302547...      7670  BR  Brasil
# 16  [{'label': 'display', 'lat': -22.9570316046702...      7342  BR  Brasil
# 17  [{'label': 'display', 'lat': -22.9065750542830...     24413  BR  Brasil
# 18  [{'label': 'display', 'lat': -22.9550056457519...      9019  BR  Brasil
# 19  [{'label': 'display', 'lat': -22.9522120549067...     36421  BR  Brasil
# 20  [{'label': 'display', 'lat': -22.9538321195999...     13049  BR  Brasil
# 21  [{'label': 'display', 'lat': -22.9578598855093...     17202  BR  Brasil
# 22  [{'label': 'display', 'lat': -22.9266077912595...     22870  BR  Brasil
# 23  [{'label': 'display', 'lat': -22.92903, 'lng':...      5428  BR  Brasil
# 24  [{'label': 'display', 'lat': -22.9675502875147...     13161  BR  Brasil
# 25  [{'label': 'display', 'lat': -22.9567757449656...      7583  BR  Brasil
# 26  [{'label': 'display', 'lat': -22.8389621383986...     27094  BR  Brasil
# 27  [{'label': 'display', 'lat': -22.7444286346435...     19869  BR  Brasil
# 28  [{'label': 'display', 'lat': -22.7846069335937...     15050  BR  Brasil
# 29  [{'label': 'display', 'lat': -22.9608602941512...     17135  BR  Brasil
#
#                                      formattedAddress            city state  \
# 0                                    [Maricá, Brasil]             NaN   NaN
# 1                                            [Brasil]             NaN   NaN
# 2                                            [Brasil]             NaN   NaN
# 3                                            [Brasil]             NaN   NaN
# 4         [Rua Alvares de Castro, Maricá, RJ, Brasil]          Maricá    RJ
# 5   [Estrada Velha Maricá (Lote 1 - Itapeba), Mari...          Maricá    RJ
# 6   [Rua Raul Alfredo de Andrade, N.62- Loja 1, Ca...          Maricá    RJ
# 7   [R. Euclides dos Santos Quintanilha, 1-649, Ma...          Maricá    RJ
# 8   [Av. Ewerton da Costa Xavier, 1926, Niterói, R...         Niterói    RJ
# 9   [Rodovia Amaral Peixoto (ao lado do Condado), ...             NaN   NaN
# 10                    [Maricá, RJ, 24942-395, Brasil]          Maricá    RJ
# 11  [Rua João Saldanha (esquina da Rua Zero - Barr...          Maricá    RJ
# 12  [Av. Dr. Eugênio Borges, 33, São Gonçalo, RJ, ...     São Gonçalo    RJ
# 13                    [Maricá, RJ, 24913-270, Brasil]          Maricá    RJ
# 14                                           [Brasil]             NaN   NaN
# 15  [Pç. de São José do Imbassaí, Maricá, RJ, Brasil]          Maricá    RJ
# 16              [Avenida Central, Maricá, RJ, Brasil]          Maricá    RJ
# 17    [Estrada Caetano Monteiro, Niterói, RJ, Brasil]         Niterói    RJ
# 18                                           [Brasil]             NaN   NaN
# 19      [ICRJ, Rio de Janeiro, RJ, 22290-250, Brasil]  Rio de Janeiro    RJ
# 20                   [Canal, Ponta Negra, RJ, Brasil]     Ponta Negra    RJ
# 21  [Av. Vitória Régia, Qd. 15 Lt. 3, Maricá, RJ, ...          Maricá    RJ
# 22         [R. Noventa e Seis, Saquarema, RJ, Brasil]       Saquarema    RJ
# 23  [Rodovia Amaral Peixoto, km 22,5, (São José de...          Maricá    RJ
# 24                         [1, Itaipuaçu, RJ, Brasil]       Itaipuaçu    RJ
# 25                                           [Brasil]             NaN   NaN
# 26  [R. Dr. Getúlio Vargas, 1618, São Gonçalo, RJ,...     São Gonçalo    RJ
# 27                                           [Brasil]             NaN   NaN
# 28                                           [Brasil]             NaN   NaN
# 29                                           [Brasil]             NaN   NaN
#
#                               crossStreet postalCode neighborhood  \
# 0                                     NaN        NaN          NaN
# 1                                     NaN        NaN          NaN
# 2                                     NaN        NaN          NaN
# 3                                     NaN        NaN          NaN
# 4                                     NaN        NaN          NaN
# 5                        Lote 1 - Itapeba        NaN          NaN
# 6                                     NaN        NaN          NaN
# 7                                     NaN  24900-000          NaN
# 8                                     NaN        NaN          NaN
# 9                      ao lado do Condado        NaN          NaN
# 10                                    NaN  24942-395          NaN
# 11  esquina da Rua Zero - Barra de Maricá  24915-435          NaN
# 12                                    NaN  24753-000          NaN
# 13                                    NaN  24913-270          NaN
# 14                                    NaN        NaN          NaN
# 15                                    NaN        NaN          NaN
# 16                                    NaN        NaN          NaN
# 17                                    NaN        NaN          NaN
# 18                                    NaN        NaN          NaN
# 19                                    NaN  22290-250          NaN
# 20                                    NaN        NaN          NaN
# 21                                    NaN        NaN          NaN
# 22                                    NaN        NaN       Jaconé
# 23                   São José de Imbassaí  24942-395          NaN
# 24                                    NaN        NaN          NaN
# 25                                    NaN        NaN          NaN
# 26                                    NaN  24416-000          NaN
# 27                                    NaN        NaN          NaN
# 28                                    NaN        NaN          NaN
# 29                                    NaN        NaN          NaN
#
#                           id
# 0   4f42d3dde4b0a2bdc6b74f44
# 1   514ba85ee4b0050de1fe467d
# 2   50ad5cd6e4b01c608604ba15
# 3   4f5bea88e4b01f8f4c62e6dc
# 4   51a3e20c498e55762dc3b103
# 5   51329010e4b02d07e1733453
# 6   56b9356a498ea9a1a767516d
# 7   4ccb7207c9b84688a60eb6c3
# 8   4c7164e6fa49a1cdf5b9a8e3
# 9   53f93847498e117d170b3051
# 10  57aa69dc498e64d06e436323
# 11  500704f7805559aabc059351
# 12  5083543be4b06d381ae82347
# 13  5c1d77be65211f002c566490
# 14  5414e2e9498eec6ac48c7b41
# 15  4f5d2c62e4b0d8f7b7a34c58
# 16  51045b69e4b09faebb6b7708
# 17  4d76dc37586ef04d44d8dff0
# 18  52c8b240498e5c700b22206a
# 19  4cb4e5ea56fca1cd23104b18
# 20  4efe6e50b8f787cacfcfc8f9
# 21  4f1cacfee4b0c74ef32aa626
# 22  528ff04c11d241fddffa643b
# 23  58016000d67c14a880633ba1
# 24  4d571899cff7721eb54dbef5
# 25  5132ae56e4b08268835a0fe9
# 26  4d8942cbd85f3704d6ede3db
# 27  55ce97c6498e14d772f452a4
# 28  527048d511d2552924e1236a
# 29  4f404bf7e4b08a9e0a51558d

# %%
dataframe_filtered.name
# Out:
# 0                        Pizzaria Oasis
# 1                 Pizzaria do Mineiro 2
# 2                Pizzaria Paulistana II
# 3                        Pizzaria Mundi
# 4        Trayller e pizzaria do mineiro
# 5                 Pizzaria Show Itapeba
# 6     Pizzaria Dom Camilo Forno a Lenha
# 7                   Pizzaria Paulistana
# 8                     Pizzaria Di Lidia
# 9                      Pizzaria Coliseu
# 10               Pizzaria Irmãos Gêmeos
# 11                      Pizzaria Brimar
# 12                      Pizzaria D Toin
# 13                     Olivers Pizzaria
# 14                        Rafa Pizzaria
# 15                  Pizzaria do Mineiro
# 16                      Pizzaria Rainha
# 17                    Pizzaria Di Lidia
# 18                  Pizzaria Miolo Mole
# 19                        Pizzaria ICRJ
# 20                    Pizzaria Vendawal
# 21                    Pizzaria Di Lidia
# 22              Pizzaria Calçadão da 96
# 23             Domino's Pizzaria Maricá
# 24                     Pizzaria Riviera
# 25           Casa das Massas e Pizzaria
# 26                   Pizzaria Mamma Mia
# 27                             Pizzaria
# 28                pizzaria água na boca
# 29              Pizzaria do meu cumpadi
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Pizzarias em Maricá',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
